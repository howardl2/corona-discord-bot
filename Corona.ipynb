# %%
import pandas as pd
from pandas import json_normalize
import matplotlib.pyplot as plt
import datetime
import requests
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

from state_abr import states
# %matplotlib inline

# %%
url = "https://covidtracking.com/api/states/daily?state=NY"

result = requests.get(url)

df = json_normalize(result.json())

# %%
print(states)
# Out:
# {'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AS': 'American Samoa', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia', 'GU': 'Guam', 'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota', 'MO': 'Missouri', 'MP': 'Northern Mariana Islands', 'MS': 'Mississippi', 'MT': 'Montana', 'NA': 'National', 'NC': 'North Carolina', 'ND': 'North Dakota', 'NE': 'Nebraska', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada', 'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'PR': 'Puerto Rico', 'RI': 'Rhode Island', 'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia', 'VI': 'Virgin Islands', 'VT': 
# ...

# %%
df["date"] = df["date"].apply(lambda date: datetime.date(int(str(date)[0:4]), int(str(date)[4:6]), int(str(date)[6:])))

# %%
plt.plot(df["date"], df["positive"], color="blue", marker="o", linestyle="")

# %%
# one_hot = pd.get_dummies(df["positive"], drop_first=True)
# # df.drop(df["positive"], axis=1)
# df = df.join(one_hot)

# %%
df
# Out:
#           date state  positive  negative  pending hospitalized  death  total  \
# 0   2020-03-20    NY      7102   25325.0      NaN         None   35.0  32427
# 1   2020-03-19    NY      4152   18132.0      NaN         None   12.0  22284
# 2   2020-03-18    NY      2382   12215.0      NaN         None   12.0  14597
# 3   2020-03-17    NY      1700    5506.0      NaN         None    7.0   7206
# 4   2020-03-16    NY       950    4543.0      NaN         None    7.0   5493
# 5   2020-03-15    NY       729    4543.0      NaN         None    3.0   5272
# 6   2020-03-14    NY       524    2779.0      NaN         None    NaN   3303
# 7   2020-03-13    NY       421    2779.0      NaN         None    NaN   3200
# 8   2020-03-12    NY       216       NaN      NaN         None    NaN    216
# 9   2020-03-11    NY       216       NaN      NaN         None    NaN    216
# 10  2020-03-10    NY       173      92.0      NaN         None    NaN    265
# ...
